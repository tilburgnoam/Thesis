# %% [markdown]
# Thesis: Preprocessing

# %%
# Packs
import pandas as pd

# %%
df1 = pd.read_excel('/content/HIC_dataset1.xlsx')
df2 = pd.read_excel('/content/HIC_dataset2.xlsx')
df3 = pd.read_excel('/content/HIC_dataset3.xlsx')
df4 = pd.read_excel('/content/HIC_dataset4.xlsx')
df5 = pd.read_excel('/content/HIC_dataset5.xlsx')
df6 = pd.read_excel('/content/HIC_dataset6.xlsx')

pd.set_option('display.max_colwidth', None)

# %%
df2['sentiment label']
# Out:
# 0         [subjective];[Hamas: mildly negative;;medium][Israel: very positive;;high]
# 1                      [subjective];[Hamas: na;;na][Israel: mildly positive;;medium]
# 2                      [subjective];[Hamas: mildly negative;;medium][Israel: na;;na]
# 3                      [subjective];[Hamas: na;;na][Israel: mildly negative;;medium]
# 4                        [subjective];[Hamas: very negative;;medium][Israel: na;;na]
#                                              ...
# 100995                 [subjective];[Hamas: mildly negative;;medium][Israel: na;;na]
# 100996                 [subjective];[Hamas: mildly positive;;medium][Israel: na;;na]
# 100997                 [subjective];[Hamas: mildly negative;;medium][Israel: na;;na]
# 100998    [subjective];[Hamas: mildly negative;;medium][Israel: very positive;;high]
# 100999                   [subjective];[Hamas: very negative;;medium][Israel: na;;na]
# Name: sentiment label, Length: 101000, dtype: object

# %%
# concat it all
df = pd.concat([df1, df2, df3, df4, df5, df6])

# %%
df.columns
# Out:
# Index(['tweet_ID', 'tweet_pub_time', 'tweet_text', 'tweet_likes',
#        'tweet_replies', 'tweet_reposts', 'account_ID', 'following_num',
#        'followers_num', 'tweets_num', 'sentiment label'],
#       dtype='object')

# %%
from langdetect import detect
# @title Detect language
def detect_language(text):
    try:
        return detect(text)
    except:
        return 'error'

df['language'] = df['tweet_text'].apply(detect_language)
print(df['language'].value_counts())

## Keep only English tweets
english_usable_df = df[df['language'] == 'en'].copy()

print("Number of English tweets:", english_usable_df.shape[0])
print(english_usable_df[['tweet_text', 'language']].head(5))
# Out:
# language
# en       343985
# es        89293
# pt        40681
# fr        40241
# de        20590
# tr        15921
# nl        10588
# id        10450
# it         9525
# ca         4235
# sv         4226
# hi         3041
# ar         2030
# sw         1580
# pl         1120
# fa          949
# da          900
# et          851
# fi          846
# ur          812
# no          806
# cy          731
# cs          645
# el          532
# hr          485
# af          444
# he          419
# sl          412
# tl          402
# th          366
# so          278
# ro          267
# lv          229
# ta          192
# ja           86
# kn           70
# hu           70
# ru           68
# zh-cn        60
# vi           57
# mr           54
# error        48
# lt           37
# ne           30
# uk           28
# sq           21
# ml           21
# ko           20
# gu           18
# sk           15
# te           12
# zh-tw        10
# bg            8
# pa            4
# bn            4
# mk            1
# Name: count, dtype: int64
# Number of English tweets: 343985
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 tweet_text  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                          Tel Aviv, Israel on a Thursday at 3am. Wild af. Must be because of the holiday, Sukkot. https://t.co/bnyeeWefnO
# 1                                                                                                                                                                                                                                                                                                                                                                             @swilkinsonbc So sick and tired of Israel mistreating Palestinians. Why won’t the international community intervene? https://t.co/BXoq58oyIo
# 2                                                                                                                                                                                                                            Two pieces at the Israel Museum were destroyed, the head of Athena and a statue representing the Roman god Nemesis. The vandal said they “went against Torah.” This is part of a fundamentalist Jewish turn that is terrifying. It’s most reminiscent of the Taliban. https://t.co/mVeQFoXlLG
# 3                                                                                                                                                                                                                                                                                          Israel is a constant target of both jihadists and the Biden Admin. We are going to the U.N. this week on behalf of Israel. Show your support by signing our petition to help protect our precious ally. https://t.co/zQU8S52rXr
# 7  (3 of 3) - All Christians shouldn’t have to apologize for the actions of a couple of proselytizing instigators, and those kinds of minor events should be blown out of proportion in an attempt to attack Israel, and the Jews.\n\nThat’s my whole point. Neither all Christians, nor all Jews, nor all Muslims are responsible for the actions of any of their fellow Christians, Muslims, or Jews.\n\nAlso… and I feel like I’m being redundant here, but it seems like I have to be… nothing actually happened. 🤷‍♂️
#
#   language
# 0       en
# 1       en
# 2       en
# 3       en
# 7       en
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'clean_text'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-359/3261041434.py in <cell line: 0>()
#      19
#      20
# ---> 21 print(english_usable_df['clean_text'].sample(frac=1).head(5))
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'clean_text'

# %%
# @title Saving English Tweets into csv file
english_usable_df.to_csv('Data_english_tweets.csv', index=False)

# %% [markdown]
# # From here on the English only tweets

# %%
# Import packages
import pandas as pd

# %%
df = pd.read_csv('/content/Data_english_tweets.csv')
pd.set_option('display.max_colwidth', None)

# %%
df.describe()
# Out:
#          tweet_likes  tweet_replies  tweet_reposts  following_num  \
# count  343985.000000  343985.000000  343985.000000   3.439850e+05
# mean      839.334936      78.430033     260.609710   5.669653e+03
# std      4495.969859     497.709269    1555.026392   2.292354e+04
# min         0.000000       0.000000       0.000000   0.000000e+00
# 25%        43.000000       6.000000      10.000000   5.480000e+02
# 50%       115.000000      13.000000      29.000000   1.459000e+03
# 75%       363.000000      35.000000      98.000000   4.116000e+03
# max    653917.000000   72025.000000  186378.000000   1.414791e+06
#
#        followers_num    tweets_num
# count   3.439850e+05  3.439850e+05
# mean    6.644783e+05  9.063832e+04
# std     3.370156e+06  1.553781e+05
# min     0.000000e+00  1.000000e+00
# 25%     6.619000e+03  1.238300e+04
# 50%     3.485400e+04  3.366300e+04
# 75%     1.712140e+05  9.483300e+04
# max     1.661277e+08  2.295228e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 343985 entries, 0 to 343984
# Data columns (total 12 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tweet_ID         343985 non-null  object
#  1   tweet_pub_time   343985 non-null  object
#  2   tweet_text       343985 non-null  object
#  3   tweet_likes      343985 non-null  int64
#  4   tweet_replies    343985 non-null  int64
#  5   tweet_reposts    343985 non-null  int64
#  6   account_ID       343985 non-null  object
#  7   following_num    343985 non-null  int64
#  8   followers_num    343985 non-null  int64
#  9   tweets_num       343985 non-null  int64
#  10  sentiment label  343985 non-null  object
#  11  language         343985 non-null  object
# dtypes: int64(6), object(6)
# memory usage: 31.5+ MB

# %%
df['tweet_text']
# Out:
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Tel Aviv, Israel on a Thursday at 3am. Wild af. Must be because of the holiday, Sukkot. https://t.co/bnyeeWefnO
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         @swilkinsonbc So sick and tired of Israel mistreating Palestinians. Why won’t the international community intervene? https://t.co/BXoq58oyIo
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Two pieces at the Israel Museum were destroyed, the head of Athena and a statue representing the Roman god Nemesis. The vandal said they “went against Torah.” This is part of a fundamentalist Jewish turn that is terrifying. It’s most reminiscent of the Taliban. https://t.co/mVeQFoXlLG
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Israel is a constant target of both jihadists and the Biden Admin. We are going to the U.N. this week on behalf of Israel. Show your support by signing our petition to help protect our precious ally. https://t.co/zQU8S52rXr
# 4                                                                                                                                                                                                                                                                                                                              (3 of 3) - All Christians shouldn’t have to apologize for the actions of a couple of proselytizing instigators, and those kinds of minor events should be blown out of proportion in an attempt to attack Israel, and the Jews.\n\nThat’s my whole point. Neither all Christians, nor all Jews, nor all Muslims are responsible for the actions of any of their fellow Christians, Muslims, or Jews.\n\nAlso… and I feel like I’m being redundant here, but it seems like I have to be… nothing actually happened. 🤷‍♂️
#                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 343980    Nobody should be surprised by the support of the European Union and USA empires to the Zionist state of Israel on occupied Palestine.  The history of colonization through genocide and dispossession by these empires is abundant in the history books. \n\nIt is "civilized" Europe against the "savage" indigenous people.\n\nIt is "civilization" against "barbarism" as the bigoted USA media portrays the conflict between Hamas "terrorists" vs "chosen people"\n\nImagine 500 years ago the genocide against indigenous people when no cable news were available. The corpses of the "uncivilized" people are underground and the "civilized" ones continue the carnage in the year "501" . \n The Jewish intellectual, Noam Chomsky wrote a book with the title... "THE YEAR 501: The conquest continues.\n#IsraelIsATerroristState
# 343981                                                                                                                                                                                                                                                                                                             Held hostage: Ofelia Roitman\n\n77-year-old Ofelia has been missing since October 7, when Hamas terrorists launched an assault on her Kibbutz Nir Oz. Ofelia had written to her family to tell them that terrorists were in her neighborhood. \n\nAt 9:37 a.m., the family received her last text message: “Please send help, the Palestinians are here,” she wrote.\n\nHer three children and nine grandchildren are desperate for her to come home. \n\nHelp bring Ofelia home. Demand Hamas release the hostages. #BringThemHome
# 343982                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Adam, strict adherence to international laws includes the arrest and trial of Hamas terrorists. Think about what that entails, then think about the first bullet point in your post.
# 343983                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   The truth.\nBiden is confused because his young voting base is protesting against Israel.\nBiden did not expect that,he thought their votes were safe after the student loan forgivness bribe.\nNow what will he do??\nThe WH is panicking to the point of overload.\n🤣🤣🤣🤣🤣🤣🤣
# 343984                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Jeshurun ( The upright one)❤️\nJeshurun is an endearing name for Israel, used only 4 times in the Bible. ( Deuteronomy 32:15, 33:5, 26, Is 44:2). \nA great picture of the Second Coming of Jesus Christ as the defender of Israel. Our God is the eternal God with everlasting arms. ❤️ https://t.co/vef2xDvTo0
# Name: tweet_text, Length: 343985, dtype: object

# %%
# Seperating the labels from Hamas and Israel and make new column out of it and rows
'''One will be for israel and its sentiment, and the other is hamas and sentiment
the ones with NA, will be deleted since there is not really information then provided.'''

df['sentiment label']
# Out:
# 0                          [subjective];[Hamas: na;;na][Israel: mildly positive;;medium]
# 1         [subjective];[Hamas: mildly negative;;medium][Israel: mildly negative;;medium]
# 2                          [subjective];[Hamas: na;;na][Israel: mildly negative;;medium]
# 3                 [subjective];[Hamas: very negative;;high][Israel: very positive;;high]
# 4                                    [subjective];[Hamas: na;;na][Israel: neutral;;high]
#                                                ...
# 343980        [subjective];[Hamas: mildly negative;;medium][Israel: very negative;;high]
# 343981                         [subjective];[Hamas: very negative;;high][Israel: na;;na]
# 343982                     [subjective];[Hamas: mildly negative;;medium][Israel: na;;na]
# 343983              [subjective];[Hamas: mildly negative;;medium][Israel: neutral;;high]
# 343984                     [subjective];[Hamas: na;;na][Israel: mildly positive;;medium]
# Name: sentiment label, Length: 343985, dtype: object

# %%
import re

# %%
def extract_entity_sentiment_from_label(row):
    label = row['sentiment label']
    results = []
    if not isinstance(label, str):
        return pd.DataFrame(columns=list(row.index) + ['entity', 'sentiment'])

    # Regex to capture entity and sentiment before the first ';;'
    matches = re.findall(r'\[([A-Za-z\s]+): ([^;\]]+)', label)

    for entity, sentiment in matches:
        # Add entity + sentiment to original row
        new_row = row.copy()
        new_row['entity'] = entity.strip()
        new_row['sentiment'] = sentiment.strip()
        results.append(new_row)

    return pd.DataFrame(results)

# Apply to all rows and flatten
df_expanded = pd.concat([extract_entity_sentiment_from_label(row) for _, row in df.iterrows()],
                        ignore_index=True)

print(df_expanded)
# Out:
#                  tweet_ID       tweet_pub_time  \
# 0       HIC_TWID_00000001  2023-10-06 08:05:16
# 1       HIC_TWID_00000001  2023-10-06 08:05:16
# 2       HIC_TWID_00000002  2023-10-06 08:21:41
# 3       HIC_TWID_00000002  2023-10-06 08:21:41
# 4       HIC_TWID_00000003  2023-10-06 08:22:00
# ...                   ...                  ...
# 687965  HIC_TWID_00608811  2023-10-31 07:59:51
# 687966  HIC_TWID_00608812  2023-10-31 07:59:52
# 687967  HIC_TWID_00608812  2023-10-31 07:59:52
# 687968  HIC_TWID_00608813  2023-10-31 07:59:52
# 687969  HIC_TWID_00608813  2023-10-31 07:59:52
#
#                                                                                                                                                                                                                                                                                                               tweet_text  \
# 0                                                                                                                                                                                                        Tel Aviv, Israel on a Thursday at 3am. Wild af. Must be because of the holiday, Sukkot. https://t.co/bnyeeWefnO
# 1                                                                                                                                                                                                        Tel Aviv, Israel on a Thursday at 3am. Wild af. Must be because of the holiday, Sukkot. https://t.co/bnyeeWefnO
# 2                                                                                                                                                                           @swilkinsonbc So sick and tired of Israel mistreating Palestinians. Why won’t the international community intervene? https://t.co/BXoq58oyIo
# 3                                                                                                                                                                           @swilkinsonbc So sick and tired of Israel mistreating Palestinians. Why won’t the international community intervene? https://t.co/BXoq58oyIo
# 4                          Two pieces at the Israel Museum were destroyed, the head of Athena and a statue representing the Roman god Nemesis. The vandal said they “went against Torah.” This is part of a fundamentalist Jewish turn that is terrifying. It’s most reminiscent of the Taliban. https://t.co/mVeQFoXlLG
# ...                                                                                                                                                                                                                                                                                                                  ...
# 687965                                                                                                                              Adam, strict adherence to international laws includes the arrest and trial of Hamas terrorists. Think about what that entails, then think about the first bullet point in your post.
# 687966                                     The truth.\nBiden is confused because his young voting base is protesting against Israel.\nBiden did not expect that,he thought their votes were safe after the student loan forgivness bribe.\nNow what will he do??\nThe WH is panicking to the point of overload.\n🤣🤣🤣🤣🤣🤣🤣
# 687967                                     The truth.\nBiden is confused because his young voting base is protesting against Israel.\nBiden did not expect that,he thought their votes were safe after the student loan forgivness bribe.\nNow what will he do??\nThe WH is panicking to the point of overload.\n🤣🤣🤣🤣🤣🤣🤣
# 687968  Jeshurun ( The upright one)❤️\nJeshurun is an endearing name for Israel, used only 4 times in the Bible. ( Deuteronomy 32:15, 33:5, 26, Is 44:2). \nA great picture of the Second Coming of Jesus Christ as the defender of Israel. Our God is the eternal God with everlasting arms. ❤️ https://t.co/vef2xDvTo0
# 687969  Jeshurun ( The upright one)❤️\nJeshurun is an endearing name for Israel, used only 4 times in the Bible. ( Deuteronomy 32:15, 33:5, 26, Is 44:2). \nA great picture of the Second Coming of Jesus Christ as the defender of Israel. Our God is the eternal God with everlasting arms. ❤️ https://t.co/vef2xDvTo0
#
#         tweet_likes  tweet_replies  tweet_reposts         account_ID  \
# 0               270             19             13  HIC_ACID_00000001
# 1               270             19             13  HIC_ACID_00000001
# 2                39              5              5  HIC_ACID_00000002
# 3                39              5              5  HIC_ACID_00000002
# 4              1035            184            321  HIC_ACID_00000003
# ...             ...            ...            ...                ...
# 687965          178             18             30  HIC_ACID_00013936
# 687966            9              2              4  HIC_ACID_00124010
# 687967            9              2              4  HIC_ACID_00124010
# 687968           15              6              7  HIC_ACID_00060207
# 687969           15              6              7  HIC_ACID_00060207
#
#         following_num  followers_num  tweets_num  \
# 0                  20         127068       12925
# 1                  20         127068       12925
# 2                1284           6185       19941
# 3                1284           6185       19941
# 4               19828          30463       67752
# ...               ...            ...         ...
# 687965            829          41015       48105
# 687966           3547           2734       13944
# 687967           3547           2734       13944
# 687968            339            410        3546
# 687969            339            410        3546
#
#                                                                        sentiment label  \
# 0                        [subjective];[Hamas: na;;na][Israel: mildly positive;;medium]
# 1                        [subjective];[Hamas: na;;na][Israel: mildly positive;;medium]
# 2       [subjective];[Hamas: mildly negative;;medium][Israel: mildly negative;;medium]
# 3       [subjective];[Hamas: mildly negative;;medium][Israel: mildly negative;;medium]
# 4                        [subjective];[Hamas: na;;na][Israel: mildly negative;;medium]
# ...                                                                                ...
# 687965                   [subjective];[Hamas: mildly negative;;medium][Israel: na;;na]
# 687966            [subjective];[Hamas: mildly negative;;medium][Israel: neutral;;high]
# 687967            [subjective];[Hamas: mildly negative;;medium][Israel: neutral;;high]
# 687968                   [subjective];[Hamas: na;;na][Israel: mildly positive;;medium]
# 687969                   [subjective];[Hamas: na;;na][Israel: mildly positive;;medium]
#
#        language  entity        sentiment
# 0            en   Hamas               na
# 1            en  Israel  mildly positive
# 2            en   Hamas  mildly negative
# 3            en  Israel  mildly negative
# 4            en   Hamas               na
# ...         ...     ...              ...
# 687965       en  Israel               na
# 687966       en   Hamas  mildly negative
# 687967       en  Israel          neutral
# 687968       en   Hamas               na
# 687969       en  Israel  mildly positive
#
# [687970 rows x 14 columns]

# %%
df_expanded = df_expanded[df_expanded['sentiment'] != 'na']
df_expanded = df_expanded[df_expanded['sentiment'] != 'positive']
df_expanded['sentiment'].value_counts()
# Out:
# sentiment
# mildly negative    216499
# very negative       83676
# mildly positive     72514
# neutral             64032
# very positive       23819
# Name: count, dtype: int64

# %%
df_expanded['entity'].value_counts()
# Out:
# entity
# Hamas     235417
# Israel    225123
# Name: count, dtype: int64

# %%
df_expanded.to_csv('Data_Thesis.csv', index=False)

# %% [markdown]
# # Again saved and going on witht the Data_Thesis
# Here we can actually do like the preprocessing

# %%
import pandas as pd
import re
import emoji
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from nltk import pos_tag
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_9626/1399059423.py in <cell line: 0>()
#       1 import pandas as pd
#       2 import re
# ----> 3 import emoji
#       4 from nltk.corpus import stopwords
#       5 import nltk
#
# ModuleNotFoundError: No module named 'emoji'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# filtering steps that applies in essence for the pre-trained models.
#
# However, this will be also used for the ML, and DL models.
#
# Preprocessing steps:
#
#       - Filtering non-English tweets
#       - Lowercasing
#       - Removing special characters (including “@” and “#” while preserving the remaining token)
#       - Removing URLs
#       - Emoji tokenization
#       - Replace user mentions '@' to '[USER]'
#       - Normalizing whitespace

# %%
df = pd.read_csv('/content/Data_Thesis.csv')
pd.set_option('display.max_colwidth', None)

# %%
# Lowercasing
def lowercase_text(df):
    df['New_text'] = df['tweet_text'].str.lower()
    return df

df = lowercase_text(df)
print(df['New_text'].head())
# Out:
# 0                                                                                                                                                                                  tel aviv, israel on a thursday at 3am. wild af. must be because of the holiday, sukkot. https://t.co/bnyeewefno
# 1                                                                                                                                                     @swilkinsonbc so sick and tired of israel mistreating palestinians. why won’t the international community intervene? https://t.co/bxoq58oyio
# 2                                                                                                                                                     @swilkinsonbc so sick and tired of israel mistreating palestinians. why won’t the international community intervene? https://t.co/bxoq58oyio
# 3    two pieces at the israel museum were destroyed, the head of athena and a statue representing the roman god nemesis. the vandal said they “went against torah.” this is part of a fundamentalist jewish turn that is terrifying. it’s most reminiscent of the taliban. https://t.co/mveqfoxllg
# 4                                                                  israel is a constant target of both jihadists and the biden admin. we are going to the u.n. this week on behalf of israel. show your support by signing our petition to help protect our precious ally. https://t.co/zqu8s52rxr
# Name: New_text, dtype: object

# %%
# Removing special characters (including “@” and “#” while preserving the remaining token)
# Function to remove only @ and # symbols

def remove_at_hash(text):
    """
    Replace @mentions with [USER]
    Remove # but keep the hashtag word
    """
    # Replace @username with [USER]
    text = re.sub(r'@\w+', '[USER]', text)

    # Remove # but keep the word (e.g., #Israel -> Israel)
    text = re.sub(r'#', '', text)

    return text   # ← THIS WAS MISSING

# Apply to the DataFrame column
df['New_text'] = df['New_text'].apply(remove_at_hash)

print(df['New_text'].head(5))
# Out:
# 0                                                                                                                                                                                  tel aviv, israel on a thursday at 3am. wild af. must be because of the holiday, sukkot. https://t.co/bnyeewefno
# 1                                                                                                                                                            [USER] so sick and tired of israel mistreating palestinians. why won’t the international community intervene? https://t.co/bxoq58oyio
# 2                                                                                                                                                            [USER] so sick and tired of israel mistreating palestinians. why won’t the international community intervene? https://t.co/bxoq58oyio
# 3    two pieces at the israel museum were destroyed, the head of athena and a statue representing the roman god nemesis. the vandal said they “went against torah.” this is part of a fundamentalist jewish turn that is terrifying. it’s most reminiscent of the taliban. https://t.co/mveqfoxllg
# 4                                                                  israel is a constant target of both jihadists and the biden admin. we are going to the u.n. this week on behalf of israel. show your support by signing our petition to help protect our precious ally. https://t.co/zqu8s52rxr
# Name: New_text, dtype: object

# %%
# Removing URLs
def remove_urls(df):
    url_pattern = r'http\S+|www\S+|https\S+'
    df['New_text'] = df['New_text'].str.replace(url_pattern, '', regex=True)
    return df
df = remove_urls(df)
print(df[['New_text']].head())
# Out:
#                                                                                                                                                                                                                                                                  New_text
# 0                                                                                                                                                                                tel aviv, israel on a thursday at 3am. wild af. must be because of the holiday, sukkot.
# 1                                                                                                                                                          [USER] so sick and tired of israel mistreating palestinians. why won’t the international community intervene?
# 2                                                                                                                                                          [USER] so sick and tired of israel mistreating palestinians. why won’t the international community intervene?
# 3  two pieces at the israel museum were destroyed, the head of athena and a statue representing the roman god nemesis. the vandal said they “went against torah.” this is part of a fundamentalist jewish turn that is terrifying. it’s most reminiscent of the taliban.
# 4                                                                israel is a constant target of both jihadists and the biden admin. we are going to the u.n. this week on behalf of israel. show your support by signing our petition to help protect our precious ally.

# %%
print(df[['New_text']])
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   New_text
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                 tel aviv, israel on a thursday at 3am. wild af. must be because of the holiday, sukkot.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                           [USER] so sick and tired of israel mistreating palestinians. why won’t the international community intervene?
# 2                                                                                                                                                                                                                                                                                                                                                                                                                           [USER] so sick and tired of israel mistreating palestinians. why won’t the international community intervene?
# 3                                                                                                                                                                                                                                                                   two pieces at the israel museum were destroyed, the head of athena and a statue representing the roman god nemesis. the vandal said they “went against torah.” this is part of a fundamentalist jewish turn that is terrifying. it’s most reminiscent of the taliban.
# 4                                                                                                                                                                                                                                                                                                                                 israel is a constant target of both jihadists and the biden admin. we are going to the u.n. this week on behalf of israel. show your support by signing our petition to help protect our precious ally.
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# 460535  held hostage: ofelia roitman\n\n77-year-old ofelia has been missing since october 7, when hamas terrorists launched an assault on her kibbutz nir oz. ofelia had written to her family to tell them that terrorists were in her neighborhood. \n\nat 9:37 a.m., the family received her last text message: “please send help, the palestinians are here,” she wrote.\n\nher three children and nine grandchildren are desperate for her to come home. \n\nhelp bring ofelia home. demand hamas release the hostages. bringthemhome
# 460536                                                                                                                                                                                                                                                                                                                                                adam, strict adherence to international laws includes the arrest and trial of hamas terrorists. think about what that entails, then think about the first bullet point in your post.
# 460537                                                                                                                                                                                                                                                       the truth.\nbiden is confused because his young voting base is protesting against israel.\nbiden did not expect that,he thought their votes were safe after the student loan forgivness bribe.\nnow what will he do??\nthe wh is panicking to the point of overload.\n🤣🤣🤣🤣🤣🤣🤣
# 460538                                                                                                                                                                                                                                                       the truth.\nbiden is confused because his young voting base is protesting against israel.\nbiden did not expect that,he thought their votes were safe after the student loan forgivness bribe.\nnow what will he do??\nthe wh is panicking to the point of overload.\n🤣🤣🤣🤣🤣🤣🤣
# 460539                                                                                                                                                                                                                                           jeshurun ( the upright one)❤️\njeshurun is an endearing name for israel, used only 4 times in the bible. ( deuteronomy 32:15, 33:5, 26, is 44:2). \na great picture of the second coming of jesus christ as the defender of israel. our god is the eternal god with everlasting arms. ❤️
#
# [460540 rows x 1 columns]

# %%
# Emoji tokenization
def demojize_text(text):

    if not isinstance(text, str):
        return text
    return emoji.demojize(text)

# Apply to the DataFrame column
df['New_text'] = df['New_text'].apply(demojize_text)

# Test
print(df['New_text'])
# Out:
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                   tel aviv, israel on a thursday at 3am. wild af. must be because of the holiday, sukkot.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                             [USER] so sick and tired of israel mistreating palestinians. why won’t the international community intervene?
# 2                                                                                                                                                                                                                                                                                                                                                                                                                             [USER] so sick and tired of israel mistreating palestinians. why won’t the international community intervene?
# 3                                                                                                                                                                                                                                                                     two pieces at the israel museum were destroyed, the head of athena and a statue representing the roman god nemesis. the vandal said they “went against torah.” this is part of a fundamentalist jewish turn that is terrifying. it’s most reminiscent of the taliban.
# 4                                                                                                                                                                                                                                                                                                                                   israel is a constant target of both jihadists and the biden admin. we are going to the u.n. this week on behalf of israel. show your support by signing our petition to help protect our precious ally.
#                                                                                                                                                                                                                                                                          ...
# 460535    held hostage: ofelia roitman\n\n77-year-old ofelia has been missing since october 7, when hamas terrorists launched an assault on her kibbutz nir oz. ofelia had written to her family to tell them that terrorists were in her neighborhood. \n\nat 9:37 a.m., the family received her last text message: “please send help, the palestinians are here,” she wrote.\n\nher three children and nine grandchildren are desperate for her to come home. \n\nhelp bring ofelia home. demand hamas release the hostages. bringthemhome
# 460536                                                                                                                                                                                                                                                                                                                                                  adam, strict adherence to international laws includes the arrest and trial of hamas terrorists. think about what that entails, then think about the first bullet point in your post.
# 460537                                       the truth.\nbiden is confused because his young voting base is protesting against israel.\nbiden did not expect that,he thought their votes were safe after the student loan forgivness bribe.\nnow what will he do??\nthe wh is panicking to the point of overload.\n:rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:
# 460538                                       the truth.\nbiden is confused because his young voting base is protesting against israel.\nbiden did not expect that,he thought their votes were safe after the student loan forgivness bribe.\nnow what will he do??\nthe wh is panicking to the point of overload.\n:rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:
# 460539                                                                                                                                                                                                                           jeshurun ( the upright one):red_heart:\njeshurun is an endearing name for israel, used only 4 times in the bible. ( deuteronomy 32:15, 33:5, 26, is 44:2). \na great picture of the second coming of jesus christ as the defender of israel. our god is the eternal god with everlasting arms. :red_heart:
# Name: New_text, Length: 460540, dtype: object

# %%
# @title Normalizing whitespace
def normalize_whitespace(text):
    """
    Normalize whitespace by:
    - Replacing multiple spaces/tabs/newlines with a single space
    - Stripping leading/trailing whitespace
    """
    text = re.sub(r'\s+', ' ', text)  # Replace multiple whitespace with single space
    return text.strip()               # Remove leading/trailing spaces

df['New_text'] = df['New_text'].apply(normalize_whitespace)

print(df['New_text'].head())
# Out:
# 0                                                                                                                                                                                  tel aviv, israel on a thursday at 3am. wild af. must be because of the holiday, sukkot.
# 1                                                                                                                                                            [USER] so sick and tired of israel mistreating palestinians. why won’t the international community intervene?
# 2                                                                                                                                                            [USER] so sick and tired of israel mistreating palestinians. why won’t the international community intervene?
# 3    two pieces at the israel museum were destroyed, the head of athena and a statue representing the roman god nemesis. the vandal said they “went against torah.” this is part of a fundamentalist jewish turn that is terrifying. it’s most reminiscent of the taliban.
# 4                                                                  israel is a constant target of both jihadists and the biden admin. we are going to the u.n. this week on behalf of israel. show your support by signing our petition to help protect our precious ally.
# Name: New_text, dtype: object

# %%
df
# Out:
#                  tweet_ID       tweet_pub_time  \
# 0       HIC_TWID_00000001  2023-10-06 08:05:16
# 1       HIC_TWID_00000002  2023-10-06 08:21:41
# 2       HIC_TWID_00000002  2023-10-06 08:21:41
# 3       HIC_TWID_00000003  2023-10-06 08:22:00
# 4       HIC_TWID_00000004  2023-10-06 08:33:01
# ...                   ...                  ...
# 460535  HIC_TWID_00608810  2023-10-31 07:59:48
# 460536  HIC_TWID_00608811  2023-10-31 07:59:51
# 460537  HIC_TWID_00608812  2023-10-31 07:59:52
# 460538  HIC_TWID_00608812  2023-10-31 07:59:52
# 460539  HIC_TWID_00608813  2023-10-31 07:59:52
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  tweet_text  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                           Tel Aviv, Israel on a Thursday at 3am. Wild af. Must be because of the holiday, Sukkot. https://t.co/bnyeeWefnO
# 1                                                                                                                                                                                                                                                                                                                                                                                              @swilkinsonbc So sick and tired of Israel mistreating Palestinians. Why won’t the international community intervene? https://t.co/BXoq58oyIo
# 2                                                                                                                                                                                                                                                                                                                                                                                              @swilkinsonbc So sick and tired of Israel mistreating Palestinians. Why won’t the international community intervene? https://t.co/BXoq58oyIo
# 3                                                                                                                                                                                                                                             Two pieces at the Israel Museum were destroyed, the head of Athena and a statue representing the Roman god Nemesis. The vandal said they “went against Torah.” This is part of a fundamentalist Jewish turn that is terrifying. It’s most reminiscent of the Taliban. https://t.co/mVeQFoXlLG
# 4                                                                                                                                                                                                                                                                                                           Israel is a constant target of both jihadists and the Biden Admin. We are going to the U.N. this week on behalf of Israel. Show your support by signing our petition to help protect our precious ally. https://t.co/zQU8S52rXr
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# 460535  Held hostage: Ofelia Roitman\n\n77-year-old Ofelia has been missing since October 7, when Hamas terrorists launched an assault on her Kibbutz Nir Oz. Ofelia had written to her family to tell them that terrorists were in her neighborhood. \n\nAt 9:37 a.m., the family received her last text message: “Please send help, the Palestinians are here,” she wrote.\n\nHer three children and nine grandchildren are desperate for her to come home. \n\nHelp bring Ofelia home. Demand Hamas release the hostages. #BringThemHome
# 460536                                                                                                                                                                                                                                                                                                                                                 Adam, strict adherence to international laws includes the arrest and trial of Hamas terrorists. Think about what that entails, then think about the first bullet point in your post.
# 460537                                                                                                                                                                                                                                                        The truth.\nBiden is confused because his young voting base is protesting against Israel.\nBiden did not expect that,he thought their votes were safe after the student loan forgivness bribe.\nNow what will he do??\nThe WH is panicking to the point of overload.\n🤣🤣🤣🤣🤣🤣🤣
# 460538                                                                                                                                                                                                                                                        The truth.\nBiden is confused because his young voting base is protesting against Israel.\nBiden did not expect that,he thought their votes were safe after the student loan forgivness bribe.\nNow what will he do??\nThe WH is panicking to the point of overload.\n🤣🤣🤣🤣🤣🤣🤣
# 460539                                                                                                                                                                                                                     Jeshurun ( The upright one)❤️\nJeshurun is an endearing name for Israel, used only 4 times in the Bible. ( Deuteronomy 32:15, 33:5, 26, Is 44:2). \nA great picture of the Second Coming of Jesus Christ as the defender of Israel. Our God is the eternal God with everlasting arms. ❤️ https://t.co/vef2xDvTo0
#
#         tweet_likes  tweet_replies  tweet_reposts         account_ID  \
# 0               270             19             13  HIC_ACID_00000001
# 1                39              5              5  HIC_ACID_00000002
# 2                39              5              5  HIC_ACID_00000002
# 3              1035            184            321  HIC_ACID_00000003
# 4                62              7             16  HIC_ACID_00000004
# ...             ...            ...            ...                ...
# 460535          825             50            438  HIC_ACID_00004514
# 460536          178             18             30  HIC_ACID_00013936
# 460537            9              2              4  HIC_ACID_00124010
# 460538            9              2              4  HIC_ACID_00124010
# 460539           15              6              7  HIC_ACID_00060207
#
#         following_num  followers_num  tweets_num  \
# 0                  20         127068       12925
# 1                1284           6185       19941
# 2                1284           6185       19941
# 3               19828          30463       67752
# 4                 185         573060       18648
# ...               ...            ...         ...
# 460535           3542         184106       25983
# 460536            829          41015       48105
# 460537           3547           2734       13944
# 460538           3547           2734       13944
# 460539            339            410        3546
#
#                                                                        sentiment label  \
# 0                        [subjective];[Hamas: na;;na][Israel: mildly positive;;medium]
# 1       [subjective];[Hamas: mildly negative;;medium][Israel: mildly negative;;medium]
# 2       [subjective];[Hamas: mildly negative;;medium][Israel: mildly negative;;medium]
# 3                        [subjective];[Hamas: na;;na][Israel: mildly negative;;medium]
# 4               [subjective];[Hamas: very negative;;high][Israel: very positive;;high]
# ...                                                                                ...
# 460535                       [subjective];[Hamas: very negative;;high][Israel: na;;na]
# 460536                   [subjective];[Hamas: mildly negative;;medium][Israel: na;;na]
# 460537            [subjective];[Hamas: mildly negative;;medium][Israel: neutral;;high]
# 460538            [subjective];[Hamas: mildly negative;;medium][Israel: neutral;;high]
# 460539                   [subjective];[Hamas: na;;na][Israel: mildly positive;;medium]
#
#        language  entity        sentiment  \
# 0            en  Israel  mildly positive
# 1            en   Hamas  mildly negative
# 2            en  Israel  mildly negative
# 3            en  Israel  mildly negative
# 4            en   Hamas    very negative
# ...         ...     ...              ...
# 460535       en   Hamas    very negative
# 460536       en   Hamas  mildly negative
# 460537       en   Hamas  mildly negative
# 460538       en  Israel          neutral
# 460539       en  Israel  mildly positive
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     New_text
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                    tel aviv, israel on a thursday at 3am. wild af. must be because of the holiday, sukkot.
# 1                                                                                                                                                                                                                                                                                                                                                                                                              [USER] so sick and tired of israel mistreating palestinians. why won’t the international community intervene?
# 2                                                                                                                                                                                                                                                                                                                                                                                                              [USER] so sick and tired of israel mistreating palestinians. why won’t the international community intervene?
# 3                                                                                                                                                                                                                                                      two pieces at the israel museum were destroyed, the head of athena and a statue representing the roman god nemesis. the vandal said they “went against torah.” this is part of a fundamentalist jewish turn that is terrifying. it’s most reminiscent of the taliban.
# 4                                                                                                                                                                                                                                                                                                                    israel is a constant target of both jihadists and the biden admin. we are going to the u.n. this week on behalf of israel. show your support by signing our petition to help protect our precious ally.
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# 460535  held hostage: ofelia roitman 77-year-old ofelia has been missing since october 7, when hamas terrorists launched an assault on her kibbutz nir oz. ofelia had written to her family to tell them that terrorists were in her neighborhood. at 9:37 a.m., the family received her last text message: “please send help, the palestinians are here,” she wrote. her three children and nine grandchildren are desperate for her to come home. help bring ofelia home. demand hamas release the hostages. bringthemhome
# 460536                                                                                                                                                                                                                                                                                                                                  adam, strict adherence to international laws includes the arrest and trial of hamas terrorists. think about what that entails, then think about the first bullet point in your post.
# 460537                            the truth. biden is confused because his young voting base is protesting against israel. biden did not expect that,he thought their votes were safe after the student loan forgivness bribe. now what will he do?? the wh is panicking to the point of overload. :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:
# 460538                            the truth. biden is confused because his young voting base is protesting against israel. biden did not expect that,he thought their votes were safe after the student loan forgivness bribe. now what will he do?? the wh is panicking to the point of overload. :rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing::rolling_on_the_floor_laughing:
# 460539                                                                                                                                                                                                               jeshurun ( the upright one):red_heart: jeshurun is an endearing name for israel, used only 4 times in the bible. ( deuteronomy 32:15, 33:5, 26, is 44:2). a great picture of the second coming of jesus christ as the defender of israel. our god is the eternal god with everlasting arms. :red_heart:
#
# [460540 rows x 15 columns]

# %%
df.to_csv('Data_Thesis_after_pre.csv', index=False)

# %% [markdown]
# # This was the preprocessing
#
# What was done is:
#   - Filtering non-English tweets
#
#   - Lowercasing (if using uncased models)
#
#   - Removing URLs (or replacing with [URL])
#
#   - Replacing @mentions → [USER]
#
#   - Removing # while keeping the token
#
#   - Emoji tokenization
#
#   - Normalizing whitespace

# %% [markdown]
# # EDA
#
#   - Example of text, entity and sentiment
#   - Class imbalance
#   - Most frequent words

# %%
# @title Import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from collections import Counter
from google.colab import files

# %%
# @title Uploading file

df = pd.read_csv('Data_Thesis_after_pre.csv')
pd.set_option('display.max_colwidth', None)

# %%
df = df[['New_text', 'entity', 'sentiment']]

# %%
# @title Example of text, entity and sentiment

df[(df['entity'] == 'Israel') & (df['sentiment'] == 'very negative')][19:20]
# Out:
#                                                                                                     New_text  \
# 893  my money is on israel false flag attacking itself so it has an excuse to steal more palestinian land…..
#
#      entity      sentiment
# 893  Israel  very negative

# %%
df[(df['entity'] == 'Hamas') & (df['sentiment'] == 'very negative')][19:20]
# Out:
#                                                                                                                                                            New_text  \
# 331  breaking : multiple civilian infrastructures hit by rockets fired by terrorists of gaza in tel aviv of israel. israelunderattack prayforisrael indiawithisrael
#
#     entity      sentiment
# 331  Hamas  very negative

# %%
# @title Amount of data
# Checking with len rows
len(df)
# Out:
# 460540

# %% [markdown]
# # Class Imbalance

# %%
# @title Sentiment proportion
print('Amount Sentiment Label:')
sentiment_amount = df['sentiment'].value_counts()
for label, amount in sentiment_amount.items():
  print(f"  {label}: {amount}")
print()
sentiment_proportions = df['sentiment'].value_counts(normalize=True) * 100
print('Proportions Sentiment Label:')
for label, percentage in sentiment_proportions.items():
  print(f"  {label}: {percentage:.2f}%")
# Out:
# Amount Sentiment Label:
#   mildly negative: 216499
#   very negative: 83676
#   mildly positive: 72514
#   neutral: 64032
#   very positive: 23819
#
# Proportions Sentiment Label:
#   mildly negative: 47.01%
#   very negative: 18.17%
#   mildly positive: 15.75%
#   neutral: 13.90%
#   very positive: 5.17%

# %%
# @title Entity proportion
print('Amount Entity Label:')
entity_amount = df['entity'].value_counts()
for label, amount in entity_amount.items():
  print(f"  {label}: {amount}")
print()
entity_proportions = df['entity'].value_counts(normalize=True) * 100
print('Proportions Entity Label:')
for label, percentage in entity_proportions.items():
  print(f"  {label}: {percentage:.2f}%")
# Out:
# Amount Entity Label:
#   Hamas: 235417
#   Israel: 225123
#
# Proportions Entity Label:
#   Hamas: 51.12%
#   Israel: 48.88%

# %%
for entity in df['entity'].unique():
  print(f"\nEntity: {entity}")
  sentiment_counts = df[df['entity'] == entity]['sentiment'].value_counts()
  print(sentiment_counts)
# Out:
# Entity: Israel
# sentiment
# mildly negative    76879
# mildly positive    53928
# neutral            50080
# very positive      23491
# very negative      20745
# Name: count, dtype: int64
#
# Entity: Hamas
# sentiment
# mildly negative    139620
# very negative       62931
# mildly positive     18586
# neutral             13952
# very positive         328
# Name: count, dtype: int64

# %%
# @title Bar Plot Hamas/Israel Sentiment Plot

# Define order
sentiment_order = [
    'very negative',
    'mildly negative',
    'neutral',
    'mildly positive',
    'very positive'
]

israel_sentiment = df[df['entity'] == 'Israel']['sentiment'].value_counts().reindex(sentiment_order)
hamas_sentiment = df[df['entity'] == 'Hamas']['sentiment'].value_counts().reindex(sentiment_order)

combined = pd.DataFrame({
    'Israel': israel_sentiment,
    'Hamas': hamas_sentiment
    }).fillna(0)

# Plot
combined.plot(kind='bar', figsize=(7,4), color=['#005EB8', '#008000'], width=0.7)

plt.xlabel('Sentiment')
plt.ylabel('Amount')
plt.title('Sentiment Comparison: Israel vs Hamas')
plt.xticks(rotation=45)
plt.legend(title='Entity')

plt.savefig('methodology_sentiment_plot.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
sentiment_counts
# Out:
# sentiment
# mildly negative    139620
# very negative       62931
# mildly positive     18586
# neutral             13952
# very positive         328
# Name: count, dtype: int64

# %% [markdown]
# Generating Most Common Words Plots
#
#   1. In general over the whole dataset
#   2. Positive
#   3. Neutral
#   4. Negative

# %%
exclude_words = {"they", "them", "this", "that", "with", "have", "from", "will", "their", "what", "about", "there", "just", "been", "more", "were" ,"like", "when"}

words = [w for w in re.findall(r'\w+', ' '.join(df['New_text']).lower())
    if len(w) > 3 and w not in exclude_words]

# %%
word_counts = Counter(words)
most_common_words = word_counts.most_common(20)

plt.figure(figsize=(10, 6))
plt.bar([word for word, _ in most_common_words], [count for _, count in most_common_words])
plt.xlabel('Word')
plt.ylabel('Frequency')
plt.title('Most Common Words In General.')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('general_wordplot.png')
plt.show()
files.download('general_wordplot.png')

# %%
# @title Merging very- and mildly-

df['sentiment'] = df['sentiment'].replace({
    'very negative'   : 'negative',
    'mildly negative' : 'negative',
    'neutral'         : 'neutral',
    'mildly positive' : 'positive',
    'very positive'   : 'positive',
})

df['sentiment'].value_counts()

# @title Initializing sentiment

df_negative = df[df['sentiment'] == 'negative']
df_neutral = df[df['sentiment'] == 'neutral']
df_positive = df[df['sentiment'] == 'positive']

# %%
# @title Negative Plot Most Common Words

exclude_words = {"they", "them", "this", "that", "with", "have", "from", "will", "their", "what", "about"}

words = [w for w in re.findall(r'\w+', ' '.join(df_negative['New_text']).lower())
    if len(w) > 3 and w not in exclude_words]

# %%
word_counts = Counter(words)
print(word_counts.most_common(20))
# Out:
# [('israel', 289954), ('hamas', 211778), ('user', 106997), ('gaza', 95764), ('people', 51231), ('israeli', 47308), ('palestine', 37471), ('palestinian', 33657), ('palestinians', 31557), ('attack', 29340), ('against', 28184), ('support', 27401), ('there', 27288), ('just', 26179), ('been', 24453), ('civilians', 24260), ('more', 23276), ('terrorists', 23168), ('were', 22798), ('world', 21746)]

# %%
word_counts = Counter(words)
most_common_words = word_counts.most_common(20)

plt.figure(figsize=(10, 6))
plt.bar([word for word, _ in most_common_words], [count for _, count in most_common_words])
plt.xlabel('Word')
plt.ylabel('Frequency')
plt.title('Most Negative Words In General.')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('negative_wordplot.png')
plt.show()
files.download('negative_wordplot.png')

# %%
# @title Neutral Plot Most Common Words

exclude_words = {"they", "them", "this", "that", "with", "have", "from", "will", "their", "what", "about"}

words = [w for w in re.findall(r'\w+', ' '.join(df_neutral['New_text']).lower())
    if len(w) > 3 and w not in exclude_words]

# %%
word_counts = Counter(words)
print(word_counts.most_common(20))
# Out:
# [('israel', 67073), ('hamas', 35974), ('gaza', 23104), ('user', 20253), ('israeli', 9194), ('palestine', 9086), ('people', 6914), ('attack', 6534), ('palestinian', 5801), ('biden', 5596), ('there', 5572), ('more', 4963), ('iran', 4651), ('been', 4592), ('just', 4345), ('were', 4066), ('says', 4032), ('conflict', 3852), ('palestinians', 3799), ('after', 3789)]

# %%
word_counts = Counter(words)
most_common_words = word_counts.most_common(20)

plt.figure(figsize=(10, 6))
plt.bar([word for word, _ in most_common_words], [count for _, count in most_common_words])
plt.xlabel('Word')
plt.ylabel('Frequency')
plt.title('Most Neutral Words In General.')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('neutral_wordplot.png')
plt.show()
files.download('neutral_wordplot.png')

# %%
# @title Positive Plot Most Common Words

exclude_words = {"they", "them", "this", "that", "with", "have", "from", "will", "their", "what", "about"}

words = [w for w in re.findall(r'\w+', ' '.join(df_positive['New_text']).lower())
    if len(w) > 3 and w not in exclude_words]

# %%
word_counts = Counter(words)
print(word_counts.most_common(20))
# Out:
# [('israel', 125777), ('hamas', 51677), ('user', 37682), ('gaza', 25418), ('people', 17834), ('support', 15499), ('israeli', 15227), ('palestine', 14701), ('against', 10703), ('palestinian', 9911), ('there', 8715), ('stand', 8698), ('terrorists', 8423), ('world', 7935), ('right', 7880), ('attack', 7844), ('palestinians', 7359), ('more', 7277), ('just', 7150), ('biden', 6881)]

# %%
word_counts = Counter(words)
most_common_words = word_counts.most_common(20)

plt.figure(figsize=(10, 6))
plt.bar([word for word, _ in most_common_words], [count for _, count in most_common_words])
plt.xlabel('Word')
plt.ylabel('Frequency')
plt.title('Most Positive Words In General.')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('positive_wordplot.png')
plt.show()
files.download('positive_wordplot.png')
